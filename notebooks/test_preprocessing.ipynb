# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from src.preprocessing import clean_text

text_en = "We are looking for a Machine Learning Engineer in Paris!"
text_fr = "Nous recherchons un ingénieur en machine learning à Paris."

print(clean_text(text_en))
print(clean_text(text_fr))
# Out:
# looking machine learning engineer paris
# compétences recherchées – temps mettre lumière entrez directement contact vaste réseau chasseurs têtes recherche active professionnels domainele marché caché l’emploi regorge d’opportunités exclusives trouverez nulle part ailleurs
